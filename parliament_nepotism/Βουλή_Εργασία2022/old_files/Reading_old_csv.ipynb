# %%
import pandas as pd

#set ups
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
pd.read_excel("Relations_the_saved.xlsx")
# Out:
#                      last_name                     first_name
# 0                  Politicians                            NaN  \
# 1                    last_name                     first_name
# 2                      Αβδελάς                      Απόστολος
# 3                       Αβέρωφ                        Ιωάννης
# 4             Αβέρωφ-Τοσίτσας                       Ευάγγελος
# 5                    Αβραμάκης                     Ελευθέριος
# 6                    Αβραμίδης                        Γαβριήλ
# 7                    Αβραμίδης                     Αλέξανδρος
# 8                 Αβραμόπουλος                      Δημήτριος
# 9                  Αγαθοπούλου                   Ειρήνη-Ελένη
# 10                      Αγάτσα                        Αριάδνη
# 11                     Αγγελής                        Ανέστης
# 12                Αγγελόπουλος                       Νικόλαος
# 13                  Αγγελούσης                      Ευστάθιος
# ...

# %%
pd.read_csv("final-edges.csv")
# Out:
#                                 Source                               Target
# 0              Θεοδωρικάκος Παναγιώτης      (Αλεξάνδρα Βλάσση-Θεοδωρικάκου)  \
# 1                 Χειμάρας Θεμιστοκλής                   Αθανάσιος Χειμάρας
# 2             Αναγνωστόπουλος Θεόδωρος            Αναγνωστόπουλος Γεώργιος*
# 3                   Ανθόπουλος Ιωάννης                 Ανθόπουλος Ευστάθιος
# 4                 Ανθόπουλος Ευστάθιος                   Ανθόπουλος Ιωάννης
# 5                      Βαλυράκης Ιωσήφ                    Βαλυράκης Ιωάννης
# 6               Βαρβιτσιώτης Μιλτιάδης                  Βαρβιτσιώτης Ιωάννη
# 7                 Βαρβιτσιώτης Ιωάννης              Βαρβιτσιώτης Μιλτιάδης*
# 8     Βολουδάκης Μανούσος-Κωνσταντίνος                  Βολουδάκης Γεώργιος
# 9                    Γεννηματά Φωτεινή                  Γεννηματάς Γεώργιος
# 10          Γιαννακοπούλου Κωνσταντίνα               Γιαννακόπουλος Ιωάννης
# ...

# %%
pd.read_csv("nodes.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 pd.read_csv("nodes.csv")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...
